# %%
import pandas as pd

# %%
dat = pd.read_table('/home/zhangyong/Downloads/task-9403296-stdout')

# %%
dat.columns
# Out:
# Index(['packagename', 'fromtype', 'pv', 'uv'], dtype='object')

# %%
app = dat[dat.packagename.notnull()]

# %%
app
# Out:
#                                    packagename fromtype     pv     uv
# 1                              com.miui.player       oc  56844  33098
# 4                                   com.xiaomi       oc   4753   2889
# 5            com.sohu.inputmethod.sogou.xiaomi       oc   5051   2318
# 6                               com.tencent.mm      app   2171   1934
# 7                              com.miui.player       un   1834   1642
# 9                               com.tencent.mm       un   1445   1132
# 11                              com.tencent.mm       oc   1735    945
# 12                        com.tencent.mobileqq      app    802    673
# 15           com.sohu.inputmethod.sogou.xiaomi       un    490    411
# 16                  com.android.quicksearchbox       oc    738    350
# 17                                  com.xiaomi       un    333    309
# 18                        com.tencent.mobileqq       oc    489    281
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4ad483e0a905> in <module>()
# ----> 1 dat.groupby(['fromtype'])()
#
# TypeError: 'DataFrameGroupBy' object is not callable
